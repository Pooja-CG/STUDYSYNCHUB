# %% [markdown]
# <a href="https://colab.research.google.com/github/Pooja-CG/STUDYSYNCHUB/blob/main/nlp_text_generation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import smtplib

# %%
from email.mime.text import MIMEText

# %%
import email.mime.text

# %%
import email.mime.text

# %%
import email.mime.multipart

# %%
from email.mime.multipart import MIMEMultipart

# %%
import random
import re
from nltk.tokenize import sent_tokenize
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

# Sample text generation using NLTK
def generate_text():
    # Define some sample text templates
    templates = [
        "Our AI-driven platform utilizes cutting-edge NLP techniques to craft personalized messages that resonate with your audience.",
        "Leveraging the power of natural language processing, our solution ensures that each email is tailored to meet the unique needs of your customers.",
        "With our advanced NLP algorithms, you can deliver targeted content that speaks directly to your audience's interests and preferences.",
        "Our platform harnesses the latest developments in NLP to analyze customer feedback and sentiment, allowing you to optimize your marketing strategy for maximum impact."
    ]
    # Choose a random template
    selected_template = random.choice(templates)
    return selected_template

# Function to generate name based on email ID
def generate_name(email):
    # Extract username from email address
    username = re.split('@', email)[0]
    # Remove any digits from username
    alphabetic_username = ''.join(filter(str.isalpha, username))
    # Capitalize first letter of username
    capitalized_username = alphabetic_username.capitalize()
    return capitalized_username

# Email content
subject = "Elevate Your Marketing Strategy with AI-Powered Email Automation"
recipient_email = "twaiba28@gmail.com"  # Replace with recipient's email address
sender_email = "studysynchub24@gmail.com"
sender_password = " rcnv gczv pium yyqi"

recipient_name = generate_name(recipient_email)

body = """
Dear {recipient_name},

I hope this email finds you well.

At , we understand the importance of effective marketing strategies in today's competitive landscape. That's why we're excited to introduce our latest innovation: AI-powered email marketing automation.

{generated_text}

Experience the future of email marketing with [Your Company Name]. Our intuitive platform empowers you to create dynamic, engaging campaigns that drive tangible results.

Interested in learning more? Schedule a personalized demo today and discover how AI-powered email automation can elevate your marketing efforts to new heights.

Thank you for considering [Your Company Name] as your partner in success.

Best regards,

[Software developer]
[Pooja.C.G,Rakshitha.S,Sherly.S,Twaiba Nasreen]
[IPEC Solutions pvt ltd]
""".format(recipient_name=recipient_name, generated_text=generate_text())

# Create message container
msg = MIMEMultipart()
msg['From'] = sender_email
msg['To'] = recipient_email
msg['Subject'] = subject

# Attach body
msg.attach(MIMEText(body, 'plain'))

# Connect to SMTP server

server = smtplib.SMTP('smtp.gmail.com', 587)  # Replace with your SMTP server and port
server.starttls()

# Login to email account
server.login(sender_email, sender_password)

# Send email
server.sendmail(sender_email, recipient_email, msg.as_string())

# Quit server
server.quit()

print("Email sent successfully!")
# Out:
# Email sent successfully!

# %% [markdown]
# ![nlp.png](data:image/png;base64,...)

# %%
import random
import re
from nltk.tokenize import sent_tokenize
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

# Sample text generation using NLTK
def generate_text():
    # Define some sample text templates
    templates = [
        "Our AI-driven platform utilizes cutting-edge NLP techniques to craft personalized messages that resonate with your audience.",
        "Leveraging the power of natural language processing, our solution ensures that each email is tailored to meet the unique needs of your customers.",
        "With our advanced NLP algorithms, you can deliver targeted content that speaks directly to your audience's interests and preferences.",
        "Our platform harnesses the latest developments in NLP to analyze customer feedback and sentiment, allowing you to optimize your marketing strategy for maximum impact."
    ]
    # Choose a random template
    selected_template = random.choice(templates)
    return selected_template

# Function to generate name based on email ID
def generate_name(email):
    # Extract username from email address
    username = re.split('@', email)[0]
    # Remove any digits from username
    alphabetic_username = ''.join(filter(str.isalpha, username))
    # Capitalize first letter of username
    capitalized_username = alphabetic_username.capitalize()
    return capitalized_username

# Email content
subject = "Unlock Your Potential with IPEC Solutions Courses"
recipient_email = "twaiba28@gmail.com"  # Replace with recipient's email address
sender_email = "studysynchub24@gmail.com"
sender_password = "wblu hgsb pwrm ofek"

recipient_name = generate_name(recipient_email)

body = """
Dear {recipient_name},

I hope this email finds you well.

Are you ready to take your career to the next level? Look no further than IPEC Solutions - your partner in professional development and success.

At IPEC Solutions, we specialize in offering industry-leading courses designed to equip individuals like you with the skills and knowledge needed to excel in today's competitive landscape.

Whether you're looking to enhance your technical expertise, sharpen your leadership abilities, or explore the latest trends in your field, our comprehensive range of courses has something for everyone.

Why choose IPEC Solutions?

1. Expert Instructors: Learn from seasoned professionals and thought leaders with real-world experience in their respective industries.

2. Flexible Learning Options: Enjoy the flexibility of online courses, on-site training, or blended learning programs tailored to fit your schedule and preferences.

3. Practical Curriculum: Gain practical insights and hands-on experience through interactive workshops, case studies, and simulations that bring learning to life.

4. Career Advancement: Acquire valuable certifications and credentials recognized by employers worldwide, helping you stand out in today's job market.

Ready to embark on your learning journey with IPEC Solutions? Explore our course catalog today and take the first step towards unlocking your full potential.

Thank you for considering IPEC Solutions as your trusted partner in professional development. We look forward to helping you achieve your goals and aspirations.

Best regards,

[Software developer]
[Pooja.C.G,Rakshitha.S,Sherly.S,Twaiba Nasreen]
[IPEC Solutions pvt ltd]

""".format(recipient_name=recipient_name)

# Create message container
msg = MIMEMultipart()
msg['From'] = sender_email
msg['To'] = recipient_email
msg['Subject'] = subject

# Attach body
msg.attach(MIMEText(body, 'plain'))

# Connect to SMTP server
server = smtplib.SMTP('smtp.gmail.com', 587)  # Replace with your SMTP server and port
server.starttls()

# Login to email account
server.login(sender_email, sender_password)

# Send email
server.sendmail(sender_email, recipient_email, msg.as_string())

# Quit server
server.quit()

print("Email sent successfully!")
# Out:
# Email sent successfully!

# %%
import imaplib
import email
import smtplib
from email.mime.text import MIMEText
from email.mime.multipart import MIMEMultipart
import time

def send_autoresponse(sender_email):
    # Email content for autoresponse
    subject = "Autoresponse"
    body = "Thank you for your email. We will get back to you shortly."

    # Create message
    message = MIMEMultipart()
    message["From"] = "studysynchub24@gmail.com"
    message["To"] = sender_email
    message["Subject"] = subject
    message.attach(MIMEText(body, "plain"))

# %%
sender_email = "poojacg48@gmail.com"

# %%
def send_autoresponse(sender_email, message):
   # Connect to SMTP server and send autoresponse
   with smtplib.SMTP("smtp.gmail.com", 587) as server:
      server.starttls()
      server.login("studysynchub24@gmail.com", "wblu hgsb pwrm ofek")
      server.sendmail("studysynchub24@gmail.com", sender_email, message.as_string())

   print("Autoresponse sent to:", sender_email)

# %%
# Connect to SMTP server and send autoresponse
with smtplib.SMTP("smtp.gmail.com", 587) as server:
   server.starttls()
   server.login("studysynchub24@gmail.com", "wblu hgsb pwrm ofek")
   sender_email = "poojacg48@gmail.com"

   # Define the message to be sent
   subject = "Thank you for interest!Exclusive offers inside"
   message = "Thank you for your email. We will get back to you shortly."

   # Send the email
   server.sendmail("poojacg48@gmail.com", sender_email, message)

print("Autoresponse sent to:", sender_email)
# Out:
# Autoresponse sent to: poojacg48@gmail.com

# %%
def send_autoresponse(sender_email):
    # Email content for autoresponse
    subject = "Autoresponse"
    body = "Thank you for your email. We will get back to you shortly."

    # Create message
    message = MIMEMultipart()
    message["From"] = "studysynchub24@gmail.com"
    message["To"] = sender_email
    message["Subject"] = subject
    message.attach(MIMEText(body, "plain"))
